# %%
import os

# %%
print('Current Working Directory is:', os.getcwd())
# Out:
# Current Working Directory is: c:\Users\RAC-L-1001\Documents\data science

# %%
files = os.listdir()
print('Files in current working directory',files)
# Out:
# Files in current working directory ['.git', 'abc.py', 'armstrome.py', 'assignment1.ipynb', 'basics.ipynb', 'conditions.ipynb', 'Data Structure', 'dict.ipynb', 'fibonacci .py', 'filehandling.ipynb', 'Flask', 'function.ipynb', 'loops.ipynb', 'numpy.ipynb', 'operators.ipynb', 'pallindrome.py', 'pattern.py', 'prime.py', 'set.ipynb', 'strings.ipynb']

# %%
files = os.listdir(r"c:\Users\RAC-L-1001\Documents\data science")
print('Files in Current working directory ',files)
# Out:
# Files in Current working directory  ['.git', 'abc.py', 'armstrome.py', 'assignment1.ipynb', 'basics.ipynb', 'conditions.ipynb', 'Data Structure', 'dict.ipynb', 'fibonacci .py', 'filehandling.ipynb', 'Flask', 'function.ipynb', 'loops.ipynb', 'numpy.ipynb', 'operators.ipynb', 'pallindrome.py', 'pattern.py', 'prime.py', 'set.ipynb', 'strings.ipynb']

# %%
total_files = 0 
for path, folders,files in os.walk(r"c:\Users\RAC-L-1001\Documents\data science"):
    print('=>',path)
    print('📂',folders)
    print('🗄️',files)
    total_files += len(files)
print('Total files in directory tree:',total_files)
# Out:
# => c:\Users\RAC-L-1001\Documents\data science
# 📂 ['.git', 'Data Structure', 'Flask']
# 🗄️ ['abc.py', 'armstrome.py', 'assignment1.ipynb', 'basics.ipynb', 'conditions.ipynb', 'dict.ipynb', 'fibonacci .py', 'filehandling.ipynb', 'function.ipynb', 'loops.ipynb', 'numpy.ipynb', 'operators.ipynb', 'pallindrome.py', 'pattern.py', 'prime.py', 'set.ipynb', 'strings.ipynb']
# => c:\Users\RAC-L-1001\Documents\data science\.git
# 📂 ['hooks', 'info', 'logs', 'objects', 'refs']
# 🗄️ ['COMMIT_EDITMSG', 'config', 'description', 'FETCH_HEAD', 'HEAD', 'index']
# => c:\Users\RAC-L-1001\Documents\data science\.git\hooks
# 📂 []
# 🗄️ ['applypatch-msg.sample', 'commit-msg.sample', 'fsmonitor-watchman.sample', 'post-update.sample', 'pre-applypatch.sample', 'pre-commit.sample', 'pre-merge-commit.sample', 'pre-push.sample', 'pre-rebase.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'push-to-checkout.sample', 'sendemail-validate.sample', 'update.sample']
# ...

# %%
files = r'c:\Users\RAC-L-1001\Documents\data science'
if os.path.exists(files):
    print('The file exists')
else:
    print('The file does not exists')
# Out:
# The file exists
